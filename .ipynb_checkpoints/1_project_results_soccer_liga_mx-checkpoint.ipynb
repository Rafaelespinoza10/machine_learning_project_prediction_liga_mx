# %% [markdown]
# # Proyecto: _Predicción de liga mx_

# %% [markdown]
# En este proyecto de machine learning tiene como objetivo predecir resultados de la liga mexicana de fútbol mediante el uso de técnicas de ML, mediante el entrenamiento de modelos como Regresión Logística, SVM y Random Forest, con el propósito de poner en práctica los conocimientos obtenidos en el último curso de ML.

# %% [markdown]
# ## Conjunto de datos: _Matches of Liga MX of the season 2016-2024_

# %% [markdown]
# ## Descripción
# This dataset contains match information from the **Liga MX (Mexico)**, covering the period from **2016 to 2024**. It includes details about matches, teams, goals, referees, venues, and results.
#
# The dataset is particularly useful for:
# - **Sports Analytics** (match outcome prediction, team performance trends).
# - **Machine Learning models** (classification, regression, clustering).
# - **Data visualization projects** with historical soccer data.
#
# ## Contexto
# Liga MX is the top professional football division in Mexico.
# This dataset aggregates **regular season matches** over multiple years, providing a solid foundation for predictive modeling (e.g., forecasting match winners or scoring trends).
#
# ## Contenido
# Each row represents a match with the following attributes:
#
# | Column                  | Description |
# |--------------------------|-------------|
# | `id`                    | Match ID |
# | `referee`               | Referee name |
# | `timezone`              | Date timezone |
# | `date`                  | Match date |
# | `venue_id`              | Venue ID |
# | `venue_name`            | Venue name |
# | `venue_city`            | Venue city |
# | `season`                | Season year |
# | `round`                 | Round type (e.g., Apertura, Clausura, Jornada X) |
# | `home_team`             | Home team name |
# | `away_team`             | Away team name |
# | `home_win`              | True if home team won |
# | `away_win`              | True if away team won |
# | `home_goals`            | Home team goals |
# | `away_goals`            | Away team goals |
# | `home_goals_half_time`  | Home team goals at halftime |
# | `away_goals_half_time`  | Away team goals at halftime |
# | `home_goals_fulltime`   | Home team total goals (regular time) |
# | `away_goals_fulltime`   | Away team total goals (regular time) |
# | `home_goals_extra_time` | Home team goals in extra time |
# | `away_goals_extratime`  | Away team goals in extra time |
# | `home_goals_penalty`    | Home team penalty goals |
# | `away_goals_penalty`    | Away team penalty goals |
#
# ## Download
# Dataset available on Kaggle:
#  [Liga MX Matches 2016–2024](https://www.kaggle.com/datasets/gerardojaimeescareo/ligamx-matches-2016-2022/data?select=2016-2024_liga_mx.csv)
#
#  *Author: Gerardo Jaime Escareño*
#  *Seasons: 2016–2024*

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Funciones auxiliares

# %%
#Construccion de la funcion que hace el reparto del data set
def train_val_test_split(df, rstate=42, shuffle=True, stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.4, random_state=rstate, shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate, shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X,y)

# %%
#Crear la etiqueta de salida, ya que esto sera un entrenamiento supervisado
def add_result_label(df):
    conditions=[
        df["home_goals"] > df["away_goals"],
        df["home_goals"] < df["away_goals"],
        df["home_goals"] == df["away_goals"]
    ]
    choices=[1,-1,0] #1 casa, 1 visitante, 0 empate
    df["Class"] = np.select(conditions, choices)
    return df

# %% [markdown]
# ### 1. Lectura y visualización del conjunto de datos

# %%
df = pd.read_csv("datasets/2016-2024_liga_mx.csv")

# %%
df.head(10)
# Out:
#        id       referee timezone                       date  venue_id  \
# 0  864095   D. Quintero      UTC  2022-07-02T02:05:00+00:00   10546.0
# 1  864096      I. Lopez      UTC  2022-07-02T22:00:00+00:00    1076.0
# 2  864094  L. Santander      UTC  2022-07-02T22:00:00+00:00    1080.0
# 3  864097      Ó. Mejía      UTC  2022-07-03T00:05:00+00:00    1087.0
# 4  864098   F. Guerrero      UTC  2022-07-03T02:05:00+00:00    7182.0
# 5  864099   A. Escobedo      UTC  2022-07-03T17:00:00+00:00    1083.0
# 6  864100  F. Hernández      UTC  2022-07-03T22:00:00+00:00    1795.0
# 7  864101      J. Pérez      UTC  2022-07-04T00:05:00+00:00    1085.0
# 8  864102      C. Ramos      UTC  2022-07-05T02:00:00+00:00    1081.0
# 9  864103   A. Escobedo      UTC  2022-07-09T00:00:00+00:00   10546.0
#
#                             venue_name                venue_city  season  \
# 0                  Estadio de Mazatlán                  Mazatlán    2022
# 1                        Estadio AKRON                   Zapopan    2022
# 2   Estadio Victoria de Aguascalientes            Aguascalientes    2022
# 3  Estadio Universitario de Nuevo León  San Nicolás de los Garza    2022
# 4                       Estadio Azteca                      D.F.    2022
# 5    Estadio Olímpico de Universitario                      D.F.    2022
# 6      Estadio Alfonso Lastras Ramírez           San Luis Potosí    2022
# 7                 Estadio Nuevo Corona                   Torreón    2022
# 8                      Estadio Hidalgo           Pachuca de Soto    2022
# 9                  Estadio de Mazatlán                  Mazatlán    2022
#
#           round           home_team  ... home_goals away_goals  \
# 0  Apertura - 1            Mazatlán  ...        2.0        4.0
# 1  Apertura - 1  Guadalajara Chivas  ...        0.0        0.0
# 2  Apertura - 1              Necaxa  ...        1.0        3.0
# 3  Apertura - 1         Tigres UANL  ...        2.0        3.0
# 4  Apertura - 1        Club America  ...        0.0        0.0
# 5  Apertura - 1    U.N.A.M. - Pumas  ...        1.0        1.0
# 6  Apertura - 1   Atletico San Luis  ...        1.0        2.0
# 7  Apertura - 1       Santos Laguna  ...        4.0        3.0
# 8  Apertura - 1             Pachuca  ...        2.0        0.0
# 9  Apertura - 2            Mazatlán  ...        0.0        1.0
#
#   home_goals_half_time  away_goals_half_time  home_goals_fulltime  \
# 0                  0.0                   2.0                  2.0
# 1                  0.0                   0.0                  0.0
# 2                  1.0                   2.0                  1.0
# 3                  0.0                   1.0                  2.0
# 4                  0.0                   0.0                  0.0
# 5                  0.0                   1.0                  1.0
# 6                  0.0                   1.0                  1.0
# 7                  2.0                   2.0                  4.0
# 8                  1.0                   0.0                  2.0
# 9                  0.0                   1.0                  0.0
#
#    away_goals_fulltime  home_goals_extra_time  away_goals_extratime  \
# 0                  4.0                    NaN                   NaN
# 1                  0.0                    NaN                   NaN
# 2                  3.0                    NaN                   NaN
# 3                  3.0                    NaN                   NaN
# 4                  0.0                    NaN                   NaN
# 5                  1.0                    NaN                   NaN
# 6                  2.0                    NaN                   NaN
# 7                  3.0                    NaN                   NaN
# 8                  0.0                    NaN                   NaN
# 9                  1.0                    NaN                   NaN
#
#    home_goals_penalty  away_goals_penalty
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
# 5                 NaN                 NaN
# 6                 NaN                 NaN
# 7                 NaN                 NaN
# 8                 NaN                 NaN
# 9                 NaN                 NaN
#
# [10 rows x 23 columns]

# %%
# Agregar la etiqueta de salida
df = add_result_label(df)
df
# Out:
#           id                            referee timezone  \
# 0     864095                        D. Quintero      UTC
# 1     864096                           I. Lopez      UTC
# 2     864094                       L. Santander      UTC
# 3     864097                           Ó. Mejía      UTC
# 4     864098                        F. Guerrero      UTC
# ...      ...                                ...      ...
# 2871  143583   Marco Antonio Ortiz Nava, Mexico      UTC
# 2872  143582             Luis Santander, Mexico      UTC
# 2873  143584  Jorge Antonio Perez Duran, Mexico      UTC
# 2874  143579               Oscar Macias, Mexico      UTC
# 2875  143580             Luis Santander, Mexico      UTC
#
#                            date  venue_id  \
# 0     2022-07-02T02:05:00+00:00   10546.0
# 1     2022-07-02T22:00:00+00:00    1076.0
# 2     2022-07-02T22:00:00+00:00    1080.0
# 3     2022-07-03T00:05:00+00:00    1087.0
# 4     2022-07-03T02:05:00+00:00    7182.0
# ...                         ...       ...
# 2871  2017-05-19T02:30:00+00:00       NaN
# 2872  2017-05-21T23:06:00+00:00       NaN
# 2873  2017-05-22T01:00:00+00:00    1088.0
# 2874  2017-05-26T02:00:00+00:00       NaN
# 2875  2017-05-28T23:06:00+00:00       NaN
#
#                                venue_name                venue_city  season  \
# 0                     Estadio de Mazatlán                  Mazatlán    2022
# 1                           Estadio AKRON                   Zapopan    2022
# 2      Estadio Victoria de Aguascalientes            Aguascalientes    2022
# 3     Estadio Universitario de Nuevo León  San Nicolás de los Garza    2022
# 4                          Estadio Azteca                      D.F.    2022
# ...                                   ...                       ...     ...
# 2871         Estadio Universitario (UANL)                 Monterrey    2016
# 2872                        Estadio Akron               Guadalajara    2016
# 2873                     Estadio Caliente                   Tijuana    2016
# 2874         Estadio Universitario (UANL)                 Monterrey    2016
# 2875                        Estadio Akron               Guadalajara    2016
#
#                        round           home_team  ... away_goals  \
# 0               Apertura - 1            Mazatlán  ...        4.0
# 1               Apertura - 1  Guadalajara Chivas  ...        0.0
# 2               Apertura - 1              Necaxa  ...        3.0
# 3               Apertura - 1         Tigres UANL  ...        3.0
# 4               Apertura - 1        Club America  ...        0.0
# ...                      ...                 ...  ...        ...
# 2871  Clausura - Semi-finals         Tigres UANL  ...        0.0
# 2872  Clausura - Semi-finals  Guadalajara Chivas  ...        1.0
# 2873  Clausura - Semi-finals        Club Tijuana  ...        2.0
# 2874       Clausura - Finals         Tigres UANL  ...        2.0
# 2875       Clausura - Finals  Guadalajara Chivas  ...        1.0
#
#      home_goals_half_time away_goals_half_time  home_goals_fulltime  \
# 0                     0.0                  2.0                  2.0
# 1                     0.0                  0.0                  0.0
# 2                     1.0                  2.0                  1.0
# 3                     0.0                  1.0                  2.0
# 4                     0.0                  0.0                  0.0
# ...                   ...                  ...                  ...
# 2871                  2.0                  0.0                  2.0
# 2872                  1.0                  0.0                  1.0
# 2873                  0.0                  0.0                  0.0
# 2874                  0.0                  2.0                  2.0
# 2875                  1.0                  0.0                  2.0
#
#       away_goals_fulltime  home_goals_extra_time  away_goals_extratime  \
# 0                     4.0                    NaN                   NaN
# 1                     0.0                    NaN                   NaN
# 2                     3.0                    NaN                   NaN
# 3                     3.0                    NaN                   NaN
# 4                     0.0                    NaN                   NaN
# ...                   ...                    ...                   ...
# 2871                  0.0                    NaN                   NaN
# 2872                  1.0                    NaN                   NaN
# 2873                  2.0                    NaN                   NaN
# 2874                  2.0                    NaN                   NaN
# 2875                  1.0                    NaN                   NaN
#
#       home_goals_penalty  away_goals_penalty  Class
# 0                    NaN                 NaN     -1
# 1                    NaN                 NaN      0
# 2                    NaN                 NaN     -1
# 3                    NaN                 NaN     -1
# 4                    NaN                 NaN      0
# ...                  ...                 ...    ...
# 2871                 NaN                 NaN      1
# 2872                 NaN                 NaN      0
# 2873                 NaN                 NaN     -1
# 2874                 NaN                 NaN      0
# 2875                 NaN                 NaN      1
#
# [2876 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2876 entries, 0 to 2875
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2876 non-null   int64
#  1   referee                2605 non-null   object
#  2   timezone               2876 non-null   object
#  3   date                   2876 non-null   object
#  4   venue_id               1976 non-null   float64
#  5   venue_name             2876 non-null   object
#  6   venue_city             2695 non-null   object
#  7   season                 2876 non-null   int64
#  8   round                  2876 non-null   object
#  9   home_team              2876 non-null   object
#  10  away_team              2876 non-null   object
#  11  home_win               2066 non-null   object
#  12  away_win               2066 non-null   object
#  13  home_goals             2813 non-null   float64
#  14  away_goals             2813 non-null   float64
#  15  home_goals_half_time   2813 non-null   float64
#  16  away_goals_half_time   2813 non-null   float64
#  17  home_goals_fulltime    2813 non-null   float64
#  18  away_goals_fulltime    2813 non-null   float64
#  19  home_goals_extra_time  16 non-null     float64
#  20  away_goals_extratime   16 non-null     float64
#  21  home_goals_penalty     14 non-null     float64
#  22  away_goals_penalty     14 non-null     float64
#  23  Class                  2876 non-null   int64
# dtypes: float64(11), int64(3), object(10)
# memory usage: 539.4+ KB

# %%
df['Class'].value_counts()
# Out:
# Class
#  1    1259
#  0     822
# -1     795
# Name: count, dtype: int64

# %%
# Checar si existen valores Nulos
df.isna().any()
# Out:
# id                       False
# referee                   True
# timezone                 False
# date                     False
# venue_id                  True
# venue_name               False
# venue_city                True
# season                   False
# round                    False
# home_team                False
# away_team                False
# home_win                  True
# away_win                  True
# home_goals                True
# away_goals                True
# home_goals_half_time      True
# away_goals_half_time      True
# home_goals_fulltime       True
# away_goals_fulltime       True
# home_goals_extra_time     True
# away_goals_extratime      True
# home_goals_penalty        True
# away_goals_penalty        True
# Class                    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# id                          0
# referee                   271
# timezone                    0
# date                        0
# venue_id                  900
# venue_name                  0
# venue_city                181
# season                      0
# round                       0
# home_team                   0
# away_team                   0
# home_win                  810
# away_win                  810
# home_goals                 63
# away_goals                 63
# home_goals_half_time       63
# away_goals_half_time       63
# home_goals_fulltime        63
# away_goals_fulltime        63
# home_goals_extra_time    2860
# away_goals_extratime     2860
# home_goals_penalty       2862
# away_goals_penalty       2862
# Class                       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id      venue_id       season   home_goals   away_goals  \
# count  2.876000e+03   1976.000000  2876.000000  2813.000000  2813.000000
# mean   5.524025e+05   3925.280870  2019.785118     1.507999     1.149662
# std    3.990387e+05   5636.598202     2.458787     1.224900     1.069424
# min    1.201580e+05   1069.000000  2016.000000     0.000000     0.000000
# 25%    1.436298e+05   1081.000000  2018.000000     1.000000     0.000000
# 50%    5.697615e+05   1087.000000  2020.000000     1.000000     1.000000
# 75%    8.642262e+05   1965.000000  2022.000000     2.000000     2.000000
# max    1.320867e+06  20476.000000  2024.000000     9.000000     6.000000
#
#        home_goals_half_time  away_goals_half_time  home_goals_fulltime  \
# count           2813.000000           2813.000000          2813.000000
# mean               0.672236              0.515819             1.505866
# std                0.807108              0.705734             1.224332
# min                0.000000              0.000000             0.000000
# 25%                0.000000              0.000000             1.000000
# 50%                0.000000              0.000000             1.000000
# 75%                1.000000              1.000000             2.000000
# max                6.000000              5.000000             9.000000
#
#        away_goals_fulltime  home_goals_extra_time  away_goals_extratime  \
# count          2813.000000              16.000000             16.000000
# mean              1.148596               0.375000              0.187500
# std               1.069074               0.885061              0.403113
# min               0.000000               0.000000              0.000000
# 25%               0.000000               0.000000              0.000000
# 50%               1.000000               0.000000              0.000000
# 75%               2.000000               0.000000              0.000000
# max               6.000000               3.000000              1.000000
#
#        home_goals_penalty  away_goals_penalty        Class
# count           14.000000           14.000000  2876.000000
# mean             2.928571            3.071429     0.161335
# std              1.328057            1.542440     0.829697
# min              1.000000            0.000000    -1.000000
# 25%              2.000000            2.250000    -1.000000
# 50%              3.000000            3.500000     0.000000
# 75%              3.000000            4.000000     1.000000
# max              6.000000            5.000000     1.000000

# %% [markdown]
# ### 2. Preparación del conjunto de datos

# %% [markdown]
# Después de un análisis riguroso, se ha notado que las características
# `home_goals_extra_time`, `away_goals_extratime`, `home_goals_penalty`,
# `away_goals_penalty`, `home_win` y `away_win` son redundantes,
# ya que se ha construido la clase etiquetada (`Class`).

# %%
df = df.drop(columns=[  'home_goals_extra_time',
    'away_goals_extratime',
    'home_goals_penalty',
    'away_goals_penalty',
    'home_win',
    'away_win',
    'venue_id'])

# %% [markdown]
# Se decidió rellenar los valores nulos en las columnas `referee` y `venue_city`
# con el valor `"Unknown"`, ya que no afectan directamente al resultado del partido
# pero permiten conservar la integridad del registro.

# %%
#Rellenar con unkown
df['referee'] = df['referee'].fillna('Unknown')
df['venue_city'] = df['venue_city'].fillna('Uknown')

# %% [markdown]
# En el caso de las columnas de goles (`home_goals`, `away_goals`,
# `home_goals_half_time`, `away_goals_half_time`, `home_goals_fulltime`,
# `away_goals_fulltime`), los valores nulos fueron reemplazados por `0`,
# pues en partidos válidos no debería haber goles sin registro.

# %%
df['home_goals'] = df['home_goals'].fillna(0)
df['away_goals'] = df['away_goals'].fillna(0)
df['home_goals_half_time'] = df['home_goals_half_time'].fillna(0) 
df['away_goals_half_time'] = df['away_goals_half_time'].fillna(0) 
df['home_goals_fulltime'] = df['home_goals_fulltime'].fillna(0) 
df['away_goals_fulltime'] = df['away_goals_fulltime'].fillna(0)

# %%
#Checar nuevamente si el data set esta libre de valores nulls
df.isna().any()
# Out:
# id                      False
# referee                 False
# timezone                False
# date                    False
# venue_name              False
# venue_city              False
# season                  False
# round                   False
# home_team               False
# away_team               False
# home_goals              False
# away_goals              False
# home_goals_half_time    False
# away_goals_half_time    False
# home_goals_fulltime     False
# away_goals_fulltime     False
# Class                   False
# dtype: bool

# %%
X = df.copy()

# %% [markdown]
# ### 2.1. Visualización de datos

# %% [markdown]
# Una vez que se han removido los valores nulos del conjunto de datos, es importante realizar una inspección de ellos, para ello, se tiene el siguiente histograma en donde se ve la relación de los features

# %%
#Quitamos la columna salida
features = df.drop("Class", axis=1)

# %%
n_features = len(features.columns)
n_cols = 4
n_rows = (n_features // n_cols) + 1

plt.figure(figsize=(20, n_rows * 4))
gs = gridspec.GridSpec(n_rows, n_cols)
gs.update(hspace=0.8)

for i, f in enumerate(features.columns):
    ax = plt.subplot(gs[i])
    if df[f].dtype == "object":
        top5 = df[f].value_counts().nlargest(5).index
        df_filtered = df[df[f].isin(top5)]
    else:
        df_filtered = df  # numéricas completas
    
    sns.histplot(data=df_filtered[df_filtered["Class"] == 1], x=f, kde=False, 
                 color="green", stat="count", label="Local gana", alpha=0.5)
    sns.histplot(data=df_filtered[df_filtered["Class"] == -1], x=f, kde=False, 
                 color="red", stat="count", label="Visita gana", alpha=0.5)
    sns.histplot(data=df_filtered[df_filtered["Class"] == 0], x=f, kde=False, 
                 color="blue", stat="count", label="Empate", alpha=0.5)
    
    ax.set_xlabel('')
    ax.set_title(f"Feature: {f} (Top 5)" if df[f].dtype == "object" else f"Feature: {f}")
    ax.legend()
    plt.xticks(rotation=45)

plt.show()

# %%
numeric_df = df.select_dtypes(include=["number"])
pca = PCA(n_components=2)

# %%
pca_result = pca.fit_transform(numeric_df.drop("Class", axis=1))

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=pca_result[:,0], y=pca_result[:,1], hue=df["Class"], palette={1:"green", -1:"red", 0:"blue"}, alpha=0.7)
plt.show()

# %% [markdown]
# La proyección de dos dimensiones muestra los partidos ganados por el equipo local (verde), visitante (rojo), y empates(azul), no presentan una separación clara utilizando unicamente las variables numericas. Esto indica que dichas caracteristicas no son suficientes para predecir el resultado, será necesario incluir variables categoricas como el equipo, estadio, y el árbrito.

# %% [markdown]
# ### 3. División del conjunto de datos

# %%
train_set, val_set, test_set = train_val_test_split(X)

# %%
X_train , y_train = remove_labels(train_set, 'Class')
X_val, y_val = remove_labels(val_set, 'Class')
X_test, y_test = remove_labels(test_set, 'Class')

# %% [markdown]
# ### 4. Preprocesamiento de los datos

# %%
#Definimos las columnas numericas
numeric_features = []  # por ahora no hay numéricas útiles previas al resultado

# %%
# Definimos las columnas categoricas
categorical_features = [
    "home_team", 
    "away_team", 
    "venue_name", 
    "venue_city", 
    "round", 
    "referee", 
    "timezone", 
    "season"
]

# %%
# Preprocesado con escalado
preprocessor_scaling = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# %%
# Preprocesador sin escalado ideal para Random Forest
preprocessor_no_scaling = ColumnTransformer(
  transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# %% [markdown]
# ### 5. Entrenamiento de los modelos

# %% [markdown]
# #### _Regresión Logistica_

# %% [markdown]
# Primero veamos el comportamiento cuando se entrena el modelo con regresión logistica para dos caracteristicas unicamente, para ello, se utilizara la selección de caracterisiticas mediante PCA

# %%
pca_pipeline = Pipeline([
    ("preprocessor", preprocessor_scaling),
    ("pca", PCA(n_components=2))
])

# %%
# Transformar los datos 
X_train_pca = pca_pipeline.fit_transform(X_train)
X_val_pca = pca_pipeline.fit_transform(X_val)
X_test_pca = pca_pipeline.fit_transform(X_test)

# %%
# Entrenar el modelo con Regresión Logistica
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Graficamos el limite de decision
plt.figure(figsize=(10,7))
x_min, x_max = X_train_pca[:, 0].min() - 1, X_train_pca[:, 0].max() + 1
y_min, y_max = X_train_pca[:, 1].min() - 1, X_train_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                     np.linspace(y_min, y_max, 300))
Z = log_reg.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.2, cmap=plt.cm.coolwarm)
sns.scatterplot(x=X_val_pca[:, 0], y=X_val_pca[:, 1], hue=y_val,
                palette={1: "green", -1: "red", 0: "blue"}, alpha=0.7)
plt.title("Límite de decisión con Logistic Regression (PCA - 2 Features)")
plt.xlabel("PCA Feature 1")
plt.ylabel("PCA Feature 2")
plt.legend(title="Class", labels=["Visita gana (-1)", "Empate (0)", "Local gana (1)"])
plt.show()

# %%
y_val_pred = log_reg.predict(X_val_pca)
# Calcular el F1 Score ponderado
print("F1 Score (Validación):", f1_score(y_val, y_val_pred, average="weighted"))
# Out:
# F1 Score (Validación): 0.27612458193979933

# %% [markdown]
# Ahora entrenamos el modelo con Regresión Logisitca con todo las caracteristicas de entrada

# %%
log_reg = Pipeline(steps=[
       ("preprocessor", preprocessor_scaling),
    ("classifier", LogisticRegression(max_iter=1000, C=0.1, penalty="l2", multi_class="multinomial", solver="lbfgs"))
])

# %%
log_reg.fit(X_train, y_train)
# Out:
# C:\Users\rafae\anaconda3\envs\CursoMachineLearning\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(), []),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['home_team', 'away_team',
#                                                    'venue_name', 'venue_city',
#                                                    'round', 'referee',
#                                                    'timezone', 'season'])])),
#                 ('classifier',
#                  LogisticRegression(C=0.1, max_iter=1000,
#                                     multi_class='multinomial'))])

# %%
#prediccion con los datos de entranmiento
y_train_pred = log_reg.predict(X_train)

# %%
print("F1 Score (Train):", f1_score(y_train, y_train_pred, average="weighted"))
# Out:
# F1 Score (Train): 0.5346667021574905

# %%
# Al parecer presenta overfiting 
y_val_pred   = log_reg.predict(X_val)

# %%
print("F1 Score (Val):", f1_score(y_val, y_val_pred, average="weighted"))
# Out:
# F1 Score (Val): 0.4188018157184805

# %%
y_test_pred  = log_reg.predict(X_test)

# %%
print("F1 Score (Test):", f1_score(y_test, y_test_pred, average="weighted"))
# Out:
# F1 Score (Test): 0.4619741778416347

# %% [markdown]
# #### _Random Forest_

# %%
# Definir modelo
rf_clf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    class_weight="balanced"  # por desbalance de clases
)

# %%
# Pipeline completo (preprocesamiento + modelo)
rf_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor_no_scaling),
    ("classifier", rf_clf)
])

# %%
# Entrenar
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough', []),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['home_team', 'away_team',
#                                                    'venue_name', 'venue_city',
#                                                    'round', 'referee',
#                                                    'timezone', 'season'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=200, random_state=42))])

# %%
y_train_pred = rf_pipeline.predict(X_train)

# %%
print("F1 Score (Train):", f1_score(y_train, y_train_pred, average="weighted"))
# Out:
# F1 Score (Train): 1.0

# %%
y_val_pred = rf_pipeline.predict(X_val)

# %%
print("F1 Score (Val):", f1_score(y_val, y_val_pred, average="weighted"))
# Out:
# F1 Score (Val): 0.43595321444441065

# %%
y_test_pred = rf_pipeline.predict(X_test)

# %%
print("F1 Score (Test):", f1_score(y_test, y_test_pred, average="weighted"))
# Out:
# F1 Score (Test): 0.4469615731350011

# %% [markdown]
# #### _Probabilidad Bayesiana_

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
# Definir modelo bayesiano
nb_clf = MultinomialNB()

# %%
# Pipeline completo (preprocesamiento + modelo)
nb_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor_scaling),
    ("classifier", nb_clf)
])

# %%
# Entrenar
nb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(), []),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['home_team', 'away_team',
#                                                    'venue_name', 'venue_city',
#                                                    'round', 'referee',
#                                                    'timezone', 'season'])])),
#                 ('classifier', MultinomialNB())])

# %%
# Predicciones
y_train_pred = nb_pipeline.predict(X_train)
# Métricas
print("F1 Score (Train):", f1_score(y_train, y_train_pred, average="weighted"))
# Out:
# F1 Score (Train): 0.5226406359150897

# %%
y_val_pred = nb_pipeline.predict(X_val)
print("F1 Score (Val):", f1_score(y_val, y_val_pred, average="weighted"))
# Out:
# F1 Score (Val): 0.4185330588572069

# %%
y_test_pred = nb_pipeline.predict(X_test)
print("F1 Score (Test):", f1_score(y_test, y_test_pred, average="weighted"))
# Out:
# F1 Score (Test): 0.44057509380036874
